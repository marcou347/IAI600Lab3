# %%
pip install pandas
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.5 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.5 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.5 MB 5.3 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.5 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.5 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 6.0/11.5 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 4.9 MB/s eta 0:00:01
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\marco\Documents\GitHub\IAI600Lab2

# %%
import pandas as pd

df = pd.read_csv(r"datasets\housing\housing.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.8 MB 4.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 5.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.8 MB 5.3 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 5.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.8 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 5.6 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Plot histograms for each numerical attribute
df.hist(figsize=(12, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.0 MB 3.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.0 MB 4.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.0 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.0 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.0 MB 4.6 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.0 MB 4.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 4.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 4.5 MB/s eta 0:00:01
# ...

# %%
from sklearn.model_selection import train_test_split

# Assuming `df` is your DataFrame
df = pd.read_csv('datasets/housing/housing.csv')

# Split the data into features (X) and target (y) if applicable
# Here, we're just splitting the entire DataFrame
X = df.copy()  # Features
y = None       # Target (if you have a specific target column, you can set y to that column)

# Split the data into training and test sets
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# Check the sizes of the sets
print(f"Training set size: {len(train_set)}")
print(f"Test set size: {len(test_set)}")
# Out:
# Training set size: 16512
# Test set size: 4128
